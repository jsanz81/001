# %%
import pandas as pd
import numpy as np
import io
import sqlite3

# %%
futbol=pd.read_csv("./bbddfut.csv", sep=";", encoding = "ISO-8859-1")

# %%
futbol.sample(10)
# Out:
#               jugador pais posicion          equipo                liga  edad
# 1263  Lennard Maloney  USA       DF        Dortmund       de Bundesliga    21  \
# 1884  Ricardo Pereira  POR       DF  Leicester City  eng Premier League    27
# 883     Isaac Success  NGA       FW         Udinese          it Serie A    25
# 120        Amine Adli  FRA    FW,MF      Leverkusen       de Bundesliga    21
# 2167     Timo HÃ¼bers  GER       DF           KÃ¶ln       de Bundesliga    25
# 2101    Steven Fortes  CPV       DF            Lens          fr Ligue 1    29
# 2245    Vitaly Janelt  GER       MF       Brentford  eng Premier League    23
# 1971      RÃºben Vezo  POR       DF         Levante          es La Liga    27
# 1069  Jordan Pickford  ENG       GK         Everton  eng Premier League    27
# 1485      Marwin Hitz  SUI       GK        Dortmund       de Bundesliga    33
#
#       partidos_jugados  partidos_titular  minutos_jugados
# ...
