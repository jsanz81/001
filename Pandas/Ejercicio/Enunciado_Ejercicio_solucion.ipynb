# %% [markdown]
# # Ejercicios

# %% [markdown]
# Los tres dataset que se encuentran la carpeta Dataset contienen:
# * **Cast**
#     * La base de datos de elenco de peliculas, de imdb.
# * **Titles**
#     * La base de datos imdb de titulos de peliculas
# * **Release_dates**
#     * La base de datos imdb de titulos de peliculas y la fecha del estreno en cada país

# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
#cambiar directorio de trabajo a Dataset
os.chdir("./Dataset")

# %%
#lista de todos los archivos csv de la carpeta Dataset
archivos_cast=[i for i in glob.glob('cast_*.csv')]

# %%
archivos_cast
# Out:
# ['cast_part_1.csv',
#  'cast_part_10.csv',
#  'cast_part_11.csv',
#  'cast_part_12.csv',
#  'cast_part_13.csv',
#  'cast_part_14.csv',
#  'cast_part_15.csv',
#  'cast_part_16.csv',
#  'cast_part_17.csv',
#  'cast_part_18.csv',
#  'cast_part_19.csv',
#  'cast_part_2.csv',
#  'cast_part_20.csv',
#  'cast_part_21.csv',
#  'cast_part_22.csv',
#  'cast_part_23.csv',
#  'cast_part_24.csv',
#  'cast_part_25.csv',
#  'cast_part_26.csv',
#  'cast_part_27.csv',
#  'cast_part_28.csv',
#  'cast_part_29.csv',
#  'cast_part_3.csv',
#  'cast_part_30.csv',
#  'cast_part_31.csv',
#  'cast_part_32.csv',
#  'cast_part_33.csv',
#  'cast_part_34.csv',
#  'cast_part_35.csv',
#  'cast_part_36.csv',
#  'cast_part_4.csv',
#  'cast_part_5.csv',
#  'cast_part_6.csv',
#  'cast_part_7.csv',
#  'cast_part_8.csv',
#  'cast_part_9.csv']

# %%
#concatenar todos los archivos cast_part_*.csv en un dataframe
cast=pd.concat([pd.read_csv(f, encoding = "ISO-8859-1",delimiter=";") for f in archivos_cast ])

# %%
cast.to_csv('cast.csv', sep=";")
#pasamos a csv para no tener que leer los csv individuales

# %% [markdown]
# ## como ya existe el archivo cast, en vez de rehacerlo entero, se lee

# %%
#como ya existe el archivo cast, en vez de rehacerlo entero, se lee
cast=pd.read_csv('cast.csv', encoding = "ISO-8859-1",delimiter=";")

# %%
#ordenado por titulo
cast.sort_values("title", ignore_index=True)
# Out:
#          Unnamed: 0.1  Unnamed: 0             title  year
# 0               20507     2120507  #1 Serial Killer  2013  \
# 1               39200     1039200  #1 Serial Killer  2013
# 2                 738      400738  #1 Serial Killer  2013
# 3               14850     1514850  #1 Serial Killer  2013
# 4               59396     2559396  #1 Serial Killer  2013
# ...               ...         ...               ...   ...
# 3564645         38031     1038031               NaN  2015
# 3564646         57093     1457093               NaN  2015
# 3564647         57158     1457158               NaN  2015
# 3564648         59465     1459465               NaN  2015
# 3564649         51768      251768               NaN  2015
#
#                          name     type           character     n
# 0             Brian Takahashi    actor     Stabbing Victim  20.0
# 1                Rane Jameson    actor    Micah Betancourt   6.0
# 2             Robert Cicchini    actor  Detective Phillips   9.0
# 3        Thomas Isao Morinaka    actor        Policeman #1  19.0
# 4              Kasie Callaway  actress          Cathherine  16.0
# ...                       ...      ...                 ...   ...
# 3564645          Landen James    actor              Landen   NaN
# 3564646          Elijah Meyer    actor     Landen's Friend   NaN
# 3564647        Emma (V) Meyer    actor  Brock's Girlfriend   NaN
# 3564648  Gabriel (II) Michael    actor          Psychopath   NaN
# 3564649          Brock Brazda    actor               Brock   NaN
#
# [3564650 rows x 8 columns]

# %%
titulos=pd.read_csv("./titles.csv", encoding="ISO-8859-1",delimiter=",")
titulos
# Out:
#                                         title  year
# 0                                      Mahler  1974
# 1                Ogon, voda i... mednye truby  1968
# 2       Ana Nojoom bent alasherah wamotalagah  2014
# 3                           Malu de Bicicleta  2010
# 4                  Nazareno Apostol: Boy Ahas  1989
# ...                                       ...   ...
# 230402                          El lobo negro  1981
# 230403                   Komu na Rusi zhit...  1989
# 230404                               Senotaji  2013
# 230405                      The Leopard Woman  1920
# 230406                     Mio caro assassino  1972
#
# [230407 rows x 2 columns]

# %%
estreno=pd.read_csv("./release_dates.csv", encoding="ISO-8859-1",delimiter=",")
estreno
# Out:
#                           title  year      country        date
# 0         #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                       #Beings  2015      Romania  2015-01-29
# 2        #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# 3                       #Horror  2015          USA  2015-11-20
# 4                       #Horror  2015           UK  2016-05-16
# ...                         ...   ...          ...         ...
# 443551  xXx: State of the Union  2005          USA  2005-04-29
# 443552  xXx: State of the Union  2005       Poland  2005-06-03
# 443553  xXx: State of the Union  2005       Turkey  2005-06-03
# 443554  xXx: State of the Union  2005        China  2005-06-17
# 443555  xXx: State of the Union  2005       Greece  2005-06-24
#
# [443556 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 1
# Del fichero **cast.csv** del la carpeta Dataset realice:

# %% [markdown]
# * Peliculas llamadas Dracula

# %%
Dracula=titulos[titulos.title=="Dracula"]
Dracula
# Out:
#           title  year
# 30479   Dracula  1992
# 35229   Dracula  1958
# 62596   Dracula  1999
# 94156   Dracula  1931
# 156968  Dracula  2019
# 184003  Dracula  1979

# %%
Dracula.shape[0]
# Out:
# 6

# %% [markdown]
# * Titulos mas comunes en la historia filmografica.

# %%
#Contar valores de columna de titulos, ordenar de más a menos
comunes=titulos.groupby(["title"])["title"].agg("count").sort_values(ascending=False).head(25)
comunes
# Out:
# title
# Hamlet                  19
# Carmen                  16
# Macbeth                 15
# Maya                    11
# The Outsider            11
# The Three Musketeers    11
# Hero                    11
# Othello                 11
# Anna                    10
# Anna Karenina           10
# Temptation              10
# Kismet                  10
# Vengeance               10
# Paradise                10
# She                     10
# Freedom                 10
# Honeymoon               10
# Borderline               9
# Wanted                   9
# Iris                     9
# Surrender                9
# No Man's Land            9
# Victory                  9
# Avalanche                9
# Underground              9
# Name: title, dtype: int64

# %% [markdown]
# * ¿Cuál fue la primer pelicula hecha titulada ``Romeo and Juliet``

# %%
#de los que coincide el título, ordenar por año y mostrar la primera fila
Romeo_Julieta=cast[["title", "year"]][cast.title=="Romeo and Juliet"].sort_values("year").head(1)
Romeo_Julieta
# Out:
#                     title  year
# 2853879  Romeo and Juliet  1916

# %% [markdown]
# * Listar todas las peliculas que contengan la palabra ``Exorcist`` ordenadas de la más antigua a la más reciente.

# %%
titulo_sin_NaN=titulos.fillna("0")
#rellena con cadena "0" los NaN

# %%
#str.contains daba error al comparar valores NaN.

exorcista=titulo_sin_NaN[titulo_sin_NaN.title.str.contains("Exorcist")].sort_values("year").set_index("title")
exorcista
# Out:
#                                         year
# title
# The Exorcist                            1973
# O Exorcista de Mulheres                 1974
# Exorcist II: The Heretic                1977
# Kung Fu Exorcist                        1978
# The Exorcist III                        1990
# Teenage Exorcist                        1991
# Exorcist: The Beginning                 2004
# Dominion: Prequel to the Exorcist       2005
# Costa Chica: Confession of an Exorcist  2006
# Exorcist Chronicles                     2007
# The Disco Exorcist                      2011
# Exorcist Chronicles                     2013
# Shark Exorcist                          2015
# Bad Exorcists                           2015
# Exorcistas                              2015
# Accidental Exorcist                     2016
# American Exorcist                       2016
# Diary of an Exorcist                    2016
# Exorcist House of Evil                  2016

# %% [markdown]
# * ¿Cuántas peliculas fueron hechas en el año 1950?

# %%
peliculas_1950=titulos[titulos.year==1950].shape[0]
peliculas_1950
# Out:
# 1081

# %% [markdown]
# * ¿Cuántas peliculas fueron hechas en el año 1970?

# %%
peliculas_1970=titulos[titulos.year==1970].shape[0]
peliculas_1970
# Out:
# 2106

# %% [markdown]
# * ¿Cuántas peliculas fueron hechas de 1950 a 1959.

# %%
peliculas_1950_1970=titulos[(titulos.year>=1950)&(titulos.year<=1959)]
peliculas_1950_1970.shape[0]
# Out:
# 12606

# %% [markdown]
# * ¿En qué años alguna pelicula llamada ``Batman`` se estrenó?

# %%
batman=titulos[titulos.title=="Batman"].set_index("title")
batman
# Out:
#         year
# title
# Batman  1989
# Batman  1943

# %% [markdown]
# * ¿Cuántos roles o papeles hubo en la pelicula ``The Godfather``?

# %%
godfather=cast[["name", "type","character"]][cast.title=="The Godfather"].set_index("type").sort_values("name")
godfather
# Out:
#                    name                character
# type
# actor        Abe Vigoda                   Tessio
# actor       Al Lettieri                 Sollozzo
# actor        Al Martino           Johnny Fontane
# actor         Al Pacino         Michael Corleone
# actor        Alex Rocco               Moe Greene
# ...                 ...                      ...
# actor         Tony King        Tony - Stablehand
# actor          Tony Lip            Wedding Guest
# actress   Tybee Brascia  Dancer in Wedding Scene
# actor    Victor Rendina         Philip Tattaglia
# actor       Vito Scotti                 Nazorine
#
# [76 rows x 2 columns]

# %%
godfather.shape[0]
# Out:
# 76

# %% [markdown]
# * ¿Cuántos papeles en la pelicula ``The Godfather`` no estan clasificados en algun valor ``n``?

# %%
# the godfather sin NaN (todos con valor n)
godfather_dropna=cast[cast.title=="The Godfather"].dropna().shape[0]
#todos los actores de Godfather - actores con valor n
godfather.shape[0]-godfather_dropna
# Out:
# 42

# %% [markdown]
# * ¿Cuántos papeles en la pelicula ``The Godfather`` si estuvieron clasificados con un valor ``n``?

# %%
# actores con valor n
godfather_dropna
# Out:
# 34

# %% [markdown]
# * Mostrar el elenco completo de la pelicula ``2001: A Space Odyssey``  ordenado por su clasificasión ``n``, ignorando los papeles que no se les asigno ningun valor ``n``.

# %%
space=cast[["name", "character", "n"]][(cast.title=="2001: A Space Odyssey")].dropna().sort_values("n")
space
# Out:
#                        name                       character     n
# 3267445         Keir Dullea                 Dr. Dave Bowman   1.0
# 488927        Gary Lockwood                 Dr. Frank Poole   2.0
# 1413186   William Sylvester            Dr. Heywood R. Floyd   3.0
# 1023947      Daniel Richter                    Moon-Watcher   4.0
# 1072093    Leonard Rossiter              Dr. Andrei Smyslov   5.0
# 2864754     Margaret Tyzack                           Elena   6.0
# 1151781       Robert Beatty             Dr. Ralph Halvorsen   7.0
# 1401643       Sean Sullivan               Dr. Bill Michaels   8.0
# 975057         Douglas Rain                        HAL 9000   9.0
# 669910         Frank Miller              Mission Controller  10.0
# 1610523         Bill Weston                       Astronaut  11.0
# 1197975           Ed Bishop  Aries-1B Lunar Shuttle Captain  12.0
# 1153470          Glenn Beck                       Astronaut  13.0
# 3452756        Alan Gifford                  Poole's Father  14.0
# 2087922          Ann Gillis                  Poole's Mother  15.0
# 1872025      Edwina Carroll             Aries-1B Stewardess  16.0
# 1829579        Penny Brahms                      Stewardess  17.0
# 1990543     Heather Downham                      Stewardess  18.0
# 502983          Mike Lovell                       Astronaut  19.0
# 85047     John (III) Ashley                             Ape  20.0
# 1161571          Jimmy Bell                             Ape  21.0
# 3037677      David Charkham                             Ape  22.0
# 3179028         Simon Davis                             Ape  23.0
# 3180285        Jonathan Daw                             Ape  24.0
# 3206413        P?ter Delm?r                             Ape  25.0
# 3266410        Terry Duggan         Ape Attacked by Leopard  26.0
# 3366727     David Fleetwood                             Ape  27.0
# 3513679        Danny Grover                             Ape  28.0
# 116925         Brian Hawley                             Ape  29.0
# 154413          David Hines                             Ape  30.0
# 230910         Tony Jackson                             Ape  31.0
# 274233      John (X) Jordan                             Ape  32.0
# 529956         Scott MacKee                             Ape  33.0
# 561809    Laurence Marchant                             Ape  34.0
# 844362          Darryl Paes                             Ape  35.0
# 1001551          Joe Refalo                             Ape  36.0
# 1573687        Andy Wallace                             Ape  37.0
# 1643583         Bob Wilyman                             Ape  38.0
# 1659428  Richard (II) Woods      Ape Killed by Moon-Watcher  39.0

# %% [markdown]
# * Mostrar el elenco completo ordenado por la clasificacion ``n`` de la pelicula ``Dracula`` de 1958

# %%
Dracula_n=cast[(cast.title=="Dracula")&(cast.year==1958)].sort_values("n")
Dracula_n
# Out:
#          Unnamed: 0.1  Unnamed: 0    title  year                   name
# 3149847         85197      485197  Dracula  1958          Peter Cushing  \
# 442307          42307     1242307  Dracula  1958        Christopher Lee
# 442308          42308     1242308  Dracula  1958        Christopher Lee
# 3487048         22398      822398  Dracula  1958          Michael Gough
# 2810427         10427     3410427  Dracula  1958      Melissa Stribling
# 2469196         69196     3069196  Dracula  1958            Carol Marsh
# 1977557         77557     2677557  Dracula  1958            Olga Dickie
# 1520986         20986     2220986  Dracula  1958        John Van Eyssen
# 2077216         77216     2777216  Dracula  1958          Valerie Gaunt
# 2031182         31182     2731182  Dracula  1958            Janina Faye
# 1744220         44220     2444220  Dracula  1958         Barbara Archer
# 485506          85506     1285506  Dracula  1958     Charles Lloyd Pack
# 653367          53367     1453367  Dracula  1958         George Merritt
# 1657769         57769     2357769  Dracula  1958      George Woodbridge
# 1171732         71732      171732  Dracula  1958          George Benson
# 547640          47640     1347640  Dracula  1958         Miles Malleson
# 1148496         48496      148496  Dracula  1958       Geoffrey Bayldon
# 3087957         23307      423307  Dracula  1958              Paul Cole
# 675047          75047     1475047  Dracula  1958              Guy Mills
# 713434          13434     1513434  Dracula  1958  Richard (VIII) Morgan
# 724497          24497     1524497  Dracula  1958      John (II) Mossman
#
#             type                 character     n
# 3149847    actor        Doctor Van Helsing   1.0
# 442307     actor                   Dracula   2.0
# 442308     actor             Count Dracula   2.0
# 3487048    actor                    Arthur   3.0
# 2810427  actress                      Mina   4.0
# 2469196  actress                      Lucy   5.0
# 1977557  actress                     Gerda   6.0
# 1520986    actor                  Jonathan   7.0
# 2077216  actress             Vampire Woman   8.0
# 2031182  actress                     Tania   9.0
# 1744220  actress                      Inga  10.0
# 485506     actor             Doctor Seward  11.0
# 653367     actor                 Policeman  12.0
# 1657769    actor                  Landlord  13.0
# 1171732    actor                  Official  14.0
# 547640     actor                Undertaker  15.0
# 1148496    actor                    Porter  16.0
# 3087957    actor                       Lad  17.0
# 675047     actor              Coach Driver   NaN
# 713434     actor  Coach Driver's Companion   NaN
# 724497     actor             Hearse Driver   NaN

# %% [markdown]
# * ¿Cuantos papeles fueron listados en la pelicula ``The Wizard of Oz`` de 1939?

# %%
Oz=cast[(cast.title=="The Wizard of Oz")&(cast.year==1939)]
Oz.shape[0]
# Out:
# 128

# %% [markdown]
# * ¿Cuántos papeles de ``Bruce Wayne`` han sido hechos en la historia de las peliculas?

# %%
bruce=cast[cast.character=="Bruce Wayne"]
bruce.shape[0]
# Out:
# 38

# %% [markdown]
# * ¿Cuánta gente ha hecho el papel de ``Romeo``?

# %%
romeo=cast[cast.character=="Romeo"]
romeo.shape[0]
# Out:
# 219

# %% [markdown]
# * ¿Cuántos papeles ha hecho ``Robert De Niro`` en su carrera?

# %%
robert_de_niro=cast[cast.name=="Robert De Niro"]
robert_de_niro.shape[0]
# Out:
# 103

# %% [markdown]
# * Listado de papeles de soporte que tuvo el actor ``Charlton Heston`` en la decada de los 50's, ordenado por año.

# %%
#Todos los papeles de Charlton Heston
charlton_heston=cast[(cast.name=="Charlton Heston")&(cast.year>=1950)&(cast.year<1960)].sort_values("year")
charlton_heston
# Out:
#         Unnamed: 0.1  Unnamed: 0                            title  year
# 144051         44051      944051                        Dark City  1950  \
# 144064         44064      944064                    Julius Caesar  1950
# 144107         44107      944107                       The Savage  1952
# 144093         44093      944093       The Greatest Show on Earth  1952
# 144108         44108      944108                       The Savage  1952
# 144080         44080      944080                      Ruby Gentry  1952
# 144104         44104      944104             The President's Lady  1953
# 144045         44045      944045                        Arrowhead  1953
# 144046         44046      944046               Bad for Each Other  1953
# 144079         44079      944079                     Pony Express  1953
# 144098         44098      944098                 The Naked Jungle  1954
# 144081         44081      944081              Secret of the Incas  1954
# 144106         44106      944106  The Private War of Major Benson  1955
# 144067         44067      944067                     Lucy Gallant  1955
# 144091         44091      944091                 The Far Horizons  1955
# 144113         44113      944113             Three Violent People  1956
# 144109         44109      944109             The Ten Commandments  1956
# 144088         44088      944088                    The Buccaneer  1958
# 144087         44087      944087                  The Big Country  1958
# 144115         44115      944115                    Touch of Evil  1958
# 144047         44047      944047                          Ben-Hur  1959
# 144112         44112      944112      The Wreck of the Mary Deare  1959
#
#                    name   type                        character    n
# 144051  Charlton Heston  actor                      Danny Haley  1.0
# 144064  Charlton Heston  actor                           Antony  2.0
# 144107  Charlton Heston  actor           James 'Jim' Aherne Jr.  1.0
# 144093  Charlton Heston  actor                      Brad Braden  3.0
# 144108  Charlton Heston  actor                       War Bonnet  1.0
# 144080  Charlton Heston  actor                    Boake Tackman  2.0
# 144104  Charlton Heston  actor         President Andrew Jackson  2.0
# 144045  Charlton Heston  actor                        Ed Bannon  1.0
# 144046  Charlton Heston  actor                     Dr. Tom Owen  1.0
# 144079  Charlton Heston  actor                Buffalo Bill Cody  1.0
# 144098  Charlton Heston  actor            Christopher Leiningen  2.0
# 144081  Charlton Heston  actor                     Harry Steele  1.0
# 144106  Charlton Heston  actor  Maj. Bernard R. 'Barney' Benson  1.0
# 144067  Charlton Heston  actor                       Casey Cole  2.0
# 144091  Charlton Heston  actor                Lt. William Clark  2.0
# 144113  Charlton Heston  actor              Capt. Colt Saunders  1.0
# 144109  Charlton Heston  actor                            Moses  1.0
# 144088  Charlton Heston  actor              Gen. Andrew Jackson  7.0
# 144087  Charlton Heston  actor                      Steve Leech  4.0
# 144115  Charlton Heston  actor                      Mike Vargas  1.0
# 144047  Charlton Heston  actor                    Judah Ben-Hur  1.0
# 144112  Charlton Heston  actor                       John Sands  2.0

# %%
charlton_heston_secundario=cast[(cast.name=="Charlton Heston")&(cast.year>=1950)&(cast.year<1960)&(cast.n!=1.0)]

# %%
charlton_heston_secundario.reset_index()
# Out:
#     index  Unnamed: 0.1  Unnamed: 0                        title  year
# 0  144064         44064      944064                Julius Caesar  1950  \
# 1  144067         44067      944067                 Lucy Gallant  1955
# 2  144080         44080      944080                  Ruby Gentry  1952
# 3  144087         44087      944087              The Big Country  1958
# 4  144088         44088      944088                The Buccaneer  1958
# 5  144091         44091      944091             The Far Horizons  1955
# 6  144093         44093      944093   The Greatest Show on Earth  1952
# 7  144098         44098      944098             The Naked Jungle  1954
# 8  144104         44104      944104         The President's Lady  1953
# 9  144112         44112      944112  The Wreck of the Mary Deare  1959
#
#               name   type                 character    n
# 0  Charlton Heston  actor                    Antony  2.0
# 1  Charlton Heston  actor                Casey Cole  2.0
# 2  Charlton Heston  actor             Boake Tackman  2.0
# 3  Charlton Heston  actor               Steve Leech  4.0
# 4  Charlton Heston  actor       Gen. Andrew Jackson  7.0
# 5  Charlton Heston  actor         Lt. William Clark  2.0
# 6  Charlton Heston  actor               Brad Braden  3.0
# 7  Charlton Heston  actor     Christopher Leiningen  2.0
# 8  Charlton Heston  actor  President Andrew Jackson  2.0
# 9  Charlton Heston  actor                John Sands  2.0

# %% [markdown]
# * Listado de papeles como protagonista que tuvo el actor ``Charlton Heston`` en la decada de los 60's, ordenado por año de forma descendente.

# %%
#Todos los principales
charlton_heston_principal=cast[(cast.name=="Charlton Heston")&(cast.year>=1950)&(cast.year<1960)&(cast.n==1.0)].sort_values("year", ascending=False).reset_index()
charlton_heston_principal
# Out:
#      index  Unnamed: 0.1  Unnamed: 0                            title  year
# 0   144047         44047      944047                          Ben-Hur  1959  \
# 1   144115         44115      944115                    Touch of Evil  1958
# 2   144109         44109      944109             The Ten Commandments  1956
# 3   144113         44113      944113             Three Violent People  1956
# 4   144106         44106      944106  The Private War of Major Benson  1955
# 5   144081         44081      944081              Secret of the Incas  1954
# 6   144045         44045      944045                        Arrowhead  1953
# 7   144046         44046      944046               Bad for Each Other  1953
# 8   144079         44079      944079                     Pony Express  1953
# 9   144107         44107      944107                       The Savage  1952
# 10  144108         44108      944108                       The Savage  1952
# 11  144051         44051      944051                        Dark City  1950
#
#                name   type                        character    n
# 0   Charlton Heston  actor                    Judah Ben-Hur  1.0
# 1   Charlton Heston  actor                      Mike Vargas  1.0
# 2   Charlton Heston  actor                            Moses  1.0
# 3   Charlton Heston  actor              Capt. Colt Saunders  1.0
# 4   Charlton Heston  actor  Maj. Bernard R. 'Barney' Benson  1.0
# 5   Charlton Heston  actor                     Harry Steele  1.0
# 6   Charlton Heston  actor                        Ed Bannon  1.0
# 7   Charlton Heston  actor                     Dr. Tom Owen  1.0
# 8   Charlton Heston  actor                Buffalo Bill Cody  1.0
# 9   Charlton Heston  actor           James 'Jim' Aherne Jr.  1.0
# 10  Charlton Heston  actor                       War Bonnet  1.0
# 11  Charlton Heston  actor                      Danny Haley  1.0

# %% [markdown]
# * ¿Cuántos papeles para actores hubo en la decada de los 50's?

# %%
actores_50s=cast[(cast.type=="actor")&(cast.year>=1950)&(cast.year<1960)]
actores_50s.shape[0]
# Out:
# 153998

# %% [markdown]
# * ¿Cuántos papeles para actrices hubo en la decada de los 50's ?

# %%
actrices_50s=cast[(cast.type=="actress")&(cast.year>=1950)&(cast.year<1960)]
actrices_50s.shape[0]
# Out:
# 56004

# %% [markdown]
# * ¿Cuantos papeles protagonistas existen desde el principio de la historia filmatografica hasta 1970 ?

# %%
papeles_1970=cast[(cast.year<1970)&(cast.n==1)]
papeles_1970.shape[0]
# Out:
# 50189

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# * Graficar la diferencia entre el numero de papeles  para actores cada año y el numero de papeles para actrices cada año en la historia de la filmografia.

# %%
import pandas as pd
import numpy as np
import glob
import os

#cambiar directorio de trabajo a Dataset
os.chdir("./Dataset")

#como ya existe el archivo cast, en vez de rehacerlo entero, se lee
cast=pd.read_csv('cast.csv', encoding = "ISO-8859-1",delimiter=";")

titulos=pd.read_csv("./titles.csv", encoding="ISO-8859-1",delimiter=",")

estreno=pd.read_csv("./release_dates.csv", encoding="ISO-8859-1",delimiter=",")

# %%
#cast.drop("Unnamed: 0.1", axis=1, inplace=True)
#cast.drop("Unnamed: 0", axis=1, inplace=True)
cast.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                 title  year      name   type
# 0             0           0        Closet Monster  2015  Buffy #1  actor  \
# 1             1           1       Suuri illusioni  1985    Homo $  actor
# 2             2           2   Battle of the Sexes  2017   $hutter  actor
# 3             3           3  Secret in Their Eyes  2015   $hutter  actor
# 4             4           4            Steve Jobs  2015   $hutter  actor
#
#                  character     n
# 0                  Buffy 4  31.0
# 1                   Guests  22.0
# 2          Bobby Riggs Fan  10.0
# 3          2002 Dodger Fan   NaN
# 4  1988 Opera House Patron   NaN

# %%
import matplotlib.pyplot as plt

# %%
actores_por_año=cast[(cast.type=="actor")].groupby("year")["type"].count()
actores_por_año
# Out:
# year
# 1894      2
# 1900      2
# 1905      1
# 1906     14
# 1907      5
#        ...
# 2019    178
# 2020     82
# 2021     16
# 2022     10
# 2023      1
# Name: type, Length: 121, dtype: int64

# %%
actrices_por_año=cast[(cast.type=="actress")].groupby("year")["type"].count()
actrices_por_año
# Out:
# year
# 1894       1
# 1906       3
# 1908      13
# 1910      24
# 1911      63
#         ...
# 2018    1053
# 2019      84
# 2020      41
# 2021       6
# 2022       7
# Name: type, Length: 116, dtype: int64

# %%
plot_actores=plt.plot(actores_por_año)
plot_actores=plt.plot(actrices_por_año)

# %% [markdown]
# * El mismo grafico anterior pero categorizado por decada y con un grafico de area.

# %%
cast["decada"]=cast["year"].astype(str).str[0:-1]+"0"

# %%
cast.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                 title  year      name   type
# 0             0           0        Closet Monster  2015  Buffy #1  actor  \
# 1             1           1       Suuri illusioni  1985    Homo $  actor
# 2             2           2   Battle of the Sexes  2017   $hutter  actor
# 3             3           3  Secret in Their Eyes  2015   $hutter  actor
# 4             4           4            Steve Jobs  2015   $hutter  actor
#
#                  character     n decada
# 0                  Buffy 4  31.0   2010
# 1                   Guests  22.0   1980
# 2          Bobby Riggs Fan  10.0   2010
# 3          2002 Dodger Fan   NaN   2010
# 4  1988 Opera House Patron   NaN   2010

# %%
#cast.drop("Unnamed: 0", axis=1, inplace=True)
#cast.drop("Unnamed: 0.1", axis=1, inplace=True)

# %%
act_por_decada=cast[["decada","type"]]
act_por_decada

decada=act_por_decada[act_por_decada.type=="actor"].groupby("decada").agg("count")
decada["actriz"]=act_por_decada[act_por_decada.type=="actress"].groupby("decada").agg("count")

# %%
decada
# Out:
#           type  actriz
# decada
# 1890         2       1
# 1900        54      16
# 1910     26917   15424
# 1920     47619   23444
# 1930    149499   48911
# 1940    160096   50794
# 1950    153998   56004
# 1960    129173   55366
# 1970    147640   64137
# 1980    192187   88658
# 1990    257429  121760
# 2000    483109  260033
# 2010    661431  370785
# 2020       109      54

# %%
plt.xticks(rotation=45)
plt.xlabel('Década',fontsize=12)
plt.title('Actores/Actrices por Década')

plot_actores=plt.plot(decada)

# %% [markdown]
# * Graficar el porcentaje de papeles que han sido actores cada año en la historia de la filmografia
# * Graficar el porcentaje de papeles que han sido  actores cada año en la historia de la filmografia junto al mismo porcentaje pero de actrices

# %%
porcentaje_actores=cast[["year", "type"]][cast.type=="actor"].groupby("year").agg("count")

# %%
porcentaje_actrices=cast[["year", "type"]][cast.type=="actress"].groupby("year").agg("count")

# %%
porcentaje_actores.rename(columns = {'type':'actor'}, inplace = True)

# %%
porcentaje_actrices.rename(columns = {'type':'actress'}, inplace = True)

# %%
porcentaje_actores["porcentaje"]=porcentaje_actores["actor"]/porcentaje_actores["actor"].sum()*100

# %%
porcentaje_actrices["porcentaje"]=porcentaje_actrices["actress"]/porcentaje_actrices["actress"].sum()*100

# %%
porcentaje_actores
# Out:
#       actor  porcentaje
# year
# 1894      2    0.000083
# 1900      2    0.000083
# 1905      1    0.000042
# 1906     14    0.000581
# 1907      5    0.000208
# ...     ...         ...
# 2019    178    0.007388
# 2020     82    0.003404
# 2021     16    0.000664
# 2022     10    0.000415
# 2023      1    0.000042
#
# [121 rows x 2 columns]

# %%
porcentaje_actrices
# Out:
#       actress  porcentaje
# year
# 1894        1    0.000087
# 1906        3    0.000260
# 1908       13    0.001125
# 1910       24    0.002077
# 1911       63    0.005453
# ...       ...         ...
# 2018     1053    0.091138
# 2019       84    0.007270
# 2020       41    0.003549
# 2021        6    0.000519
# 2022        7    0.000606
#
# [116 rows x 2 columns]

# %%
porcentaje_actores["porcentaje"].sum()
# Out:
# 100.0

# %%
porcentaje_actores.loc[2017]
# Out:
# actor         26510.000000
# porcentaje        1.100336
# Name: 2017, dtype: float64

# %%
plt.xticks(rotation=45)
plt.xlabel('Año',fontsize=12)
plt.title('% Actores/Actrices por Año')

plot_porcentaje=plt.plot(porcentaje_actores)
plot_porcentaje=plt.plot(porcentaje_actrices)

# %% [markdown]
# * Graficar 3 lineas con clasificacion "n" de 1 al 3 donde cada linea represente el porcentaje de la clasificacion para los papeles de actores en cada año.

# %%
# No entiendo esta pregunta

porcentaje_n=cast[["year", "n"]][cast.n<4].sort_values(["year", "n"]).reset_index()

# %%
#porcentaje_n.drop("index", axis=1, inplace=True)

# %%
porcentaje_n.groupby(["year", "n"]).agg("count")
# Out:
#           index
# year n
# 1906 1.0      3
#      2.0      3
#      3.0      1
# 1907 1.0      1
#      2.0      1
# ...         ...
# 2019 1.0     12
#      2.0      6
#      3.0      6
# 2020 1.0      9
#      3.0      5
#
# [342 rows x 1 columns]

# %%
porcentaje_n.groupby(["year", "n"]).agg("count").plot()
# Out:
# <Axes: xlabel='year,n'>

# %% [markdown]
# * Encontrar las 5 peliculas de la historia tengan más actrices que actores

# %%
mas_actrices=cast[["title", "type"]].groupby(["title", "type"]).count()
mas_actrices
# Out:
# Empty DataFrame
# Columns: []
# Index: [(#1 Serial Killer, actor), (#1 Serial Killer, actress), (#5, actor), (#50Fathers, actor), (#50Fathers, actress), (#66, actor), (#66, actress), (#73, Shaanthi Nivaasa, actor), (#73, Shaanthi Nivaasa, actress), (#Beings, actor), (#Beings, actress), (#DigitalLivesMatter, actor), (#DigitalLivesMatter, actress), (#Enough, actor), (#Enough, actress), (#FollowFriday, actor), (#FollowFriday, actress), (#FromJennifer, actor), (#FromJennifer, actress), (#Horror, actor), (#Horror, actress), (#Like, actress), (#Lucky Number, actor), (#Lucky Number, actress), (#Nerealnaya lyubov, actor), (#Nerealnaya lyubov, actress), (#Pellichoopulu, actor), (#Pellichoopulu, actress), (#Roxy, actor), (#Roxy, actress), (#Screamers, actor), (#Screamers, actress), (#Slaughterhouse, actor), (#Slaughterhouse, actress), (#Standards, actor), (#Standards, actress), (#Starvecrow, actor), (#Starvecrow, actress), (#Stuck, actor), (#Stuck, actress), (#Walang Forever, actor), (#Walang Forever, actress), (#WszystkoGra, actor), (#WszystkoGra, actress), (#Y, actor), (#Y, actress), (#garotas: O Filme, actor), (#garotas: O Filme, actress), (#iKllr, actor), (#iKllr, actress), (#modelswanted, actor), (#modelswanted, actress), ($, actor), ($, actress), ($10 Raise, actor), ($10 Raise, actress), ($1000 a Touchdown, actor), ($1000 a Touchdown, actress), ($40,000, actor), ($40,000, actress), ($5 a Day, actor), ($5 a Day, actress), ($5,000 Reward, actor), ($5,000 Reward, actress), ($50,000 Reward, actor), ($50,000 Reward, actress), ($50K and a Call Girl: A Love Story, actor), ($50K and a Call Girl: A Love Story, actress), ($6 Man, actor), ($6 Man, actress), ($9.99, actor), ($9.99, actress), ($elfie Shootout, actor), ($elfie Shootout, actress), ($kumbagz, actor), ($kumbagz, actress), ($pent, actor), ($pent, actress), ($tiffed or How I Learned to Deal with Dissapointment, actor), ($tiffed or How I Learned to Deal with Dissapointment, actress), ($windle, actor), ($windle, actress), (&Me, actor), (&Me, actress), ('38, actor), ('38, actress), ('49-'17, actor), ('49-'17, actress), ('68, actor), ('68, actress), ('71, actor), ('71, actress), ('77, actor), ('77, actress), ('79 Parts, actor), ('79 Parts, actress), ('85: The Greatest Team in Pro Football History, actor), ('94 du bi dao zhi qing, actor), ('94 du bi dao zhi qing, actress), ('A' gai wak, actor), ...]
#
# [324400 rows x 0 columns]

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# * En que fechas fue lanzada cada pelicula de ``Salma Hayek`` desde  1990 al presente en Mexico

# %%
peliculas_mexicanas=estreno[["title", "date"]][(estreno.country=="Mexico")&(estreno.year>=1990)]
peliculas_mexicanas

salma=cast[cast.name=="Salma Hayek"]

salma.reset_index(drop=True)
#  merge peliculas_mexicanas y salma
# Out:
#     Unnamed: 0.1  Unnamed: 0                                          title
# 0          47362     2847362                                             54  \
# 1          47363     2847363                            Across the Universe
# 2          47364     2847364                               After the Sunset
# 3          47365     2847365                                      Americano
# 4          47366     2847366                                   Ask the Dust
# 5          47367     2847367                                       Bandidas
# 6          47368     2847368                              Beatriz at Dinner
# 7          47369     2847369                                    Breaking Up
# 8          47370     2847370                                 Chain of Fools
# 9          47371     2847371       Cirque du Freak: The Vampire's Assistant
# 10         47372     2847372                                      Desperado
# 11         47373     2847373                                          Dogma
# 12         47374     2847374           El coronel no tiene quien le escriba
# 13         47375     2847375                                         Everly
# 14         47376     2847376                                      Fair Game
# 15         47377     2847377                                           Fled
# 16         47378     2847378                                 Follow Me Home
# 17         47379     2847379                                  Fools Rush In
# 18         47380     2847380                                     Four Rooms
# 19         47381     2847381                                          Frida
# 20         47382     2847382                            From Dusk Till Dawn
# 21         47383     2847383                                      Grown Ups
# 22         47384     2847384                                    Grown Ups 2
# 23         47385     2847385                            Here Comes the Boom
# 24         47386     2847386                                          Hotel
# 25         47387     2847387            How to Make Love Like an Englishman
# 26         47388     2847388       Il racconto dei racconti - Tale of Tales
# 27         47389     2847389                           La chispa de la vida
# 28         47390     2847390                                   La gran vida
# 29         47391     2847391                                  Lonely Hearts
# 30         47392     2847392                                   Mi vida loca
# 31         47393     2847393                            Muppets Most Wanted
# 32         47394     2847394                     Once Upon a Time in Mexico
# 33         47395     2847395                                  Puss in Boots
# 34         47396     2847396                                  Sausage Party
# 35         47397     2847397                                        Savages
# 36         47398     2847398                           Septembers of Shiraz
# 37         47399     2847399                        Spy Kids 3-D: Game Over
# 38         47400     2847400                                    The Faculty
# 39         47401     2847401  The Pirates! In an Adventure with Scientists!
# 40         47402     2847402                                    The Prophet
# 41         47403     2847403     The Velocity of Gary* *(Not His Real Name)
# 42         47404     2847404                                       Timecode
# 43         47405     2847405                                        Traffic
# 44         47406     2847406                           Welcome to Hollywood
# 45         47407     2847407                                 Wild Wild West
#
#     year         name     type                                    character
# 0   1998  Salma Hayek  actress                               Anita Randazzo  \
# 1   2007  Salma Hayek  actress                                Singing Nurse
# 2   2004  Salma Hayek  actress                                 Lola Cirillo
# 3   2011  Salma Hayek  actress                                       'Lola'
# 4   2006  Salma Hayek  actress                                      Camilla
# 5   2006  Salma Hayek  actress                                Sara Sandoval
# 6   2017  Salma Hayek  actress                                      Beatriz
# 7   1997  Salma Hayek  actress                                       Monica
# 8   2000  Salma Hayek  actress                                        Kolko
# 9   2009  Salma Hayek  actress                                Madame Truska
# 10  1995  Salma Hayek  actress                                     Carolina
# 11  1999  Salma Hayek  actress                                  Serendipity
# 12  1999  Salma Hayek  actress                                        Julia
# 13  2014  Salma Hayek  actress                                       Everly
# 14  1995  Salma Hayek  actress                                         Rita
# 15  1996  Salma Hayek  actress                                         Cora
# 16  1996  Salma Hayek  actress                                     Veronica
# 17  1997  Salma Hayek  actress                       Isabel Fuentes Whitman
# 18  1995  Salma Hayek  actress  TV Dancing Girl (segment "The Misbehavers")
# 19  2002  Salma Hayek  actress                                  Frida Kahlo
# 20  1996  Salma Hayek  actress                        Santanico Pandemonium
# 21  2010  Salma Hayek  actress                          Roxanne Chase-Feder
# 22  2013  Salma Hayek  actress                          Roxanne Chase-Feder
# 23  2012  Salma Hayek  actress                                 Bella Flores
# 24  2001  Salma Hayek  actress                                 Charlee Boux
# 25  2014  Salma Hayek  actress                                       Olivia
# 26  2015  Salma Hayek  actress                         Queen of Longtrellis
# 27  2011  Salma Hayek  actress                                        Luisa
# 28  2000  Salma Hayek  actress                                         Lola
# 29  2006  Salma Hayek  actress                                  Martha Beck
# 30  1993  Salma Hayek  actress                                         Gata
# 31  2014  Salma Hayek  actress                                      Herself
# 32  2003  Salma Hayek  actress                                     Carolina
# 33  2011  Salma Hayek  actress                               Kitty Softpaws
# 34  2016  Salma Hayek  actress                                       Teresa
# 35  2012  Salma Hayek  actress                                        Elena
# 36  2015  Salma Hayek  actress                                       Farnez
# 37  2003  Salma Hayek  actress                                Cesca Giggles
# 38  1998  Salma Hayek  actress                            Nurse Rosa Harper
# 39  2012  Salma Hayek  actress                                  Cutlass Liz
# 40  2014  Salma Hayek  actress                                       Kamila
# 41  1998  Salma Hayek  actress                                  Mary Carmen
# 42  2000  Salma Hayek  actress                                         Rose
# 43  2000  Salma Hayek  actress                                      Rosario
# 44  1998  Salma Hayek  actress                                      Herself
# 45  1999  Salma Hayek  actress                                 Rita Escobar
#
#        n decada
# 0    2.0   1990
# 1   66.0   2000
# 2    2.0   2000
# 3    6.0   2010
# 4    2.0   2000
# 5    2.0   2000
# 6    NaN   2010
# 7    2.0   1990
# 8    2.0   2000
# 9   12.0   2000
# 10   2.0   1990
# 11  28.0   1990
# 12   3.0   1990
# 13   1.0   2010
# 14   7.0   1990
# 15  11.0   1990
# 16   2.0   1990
# 17   2.0   1990
# 18  15.0   1990
# 19   1.0   2000
# 20   6.0   1990
# 21   6.0   2010
# 22   5.0   2010
# 23   2.0   2010
# 24  13.0   2000
# 25   2.0   2010
# 26   1.0   2010
# 27   2.0   2010
# 28   1.0   2000
# 29   4.0   2000
# 30  24.0   1990
# 31  24.0   2010
# 32   2.0   2000
# 33   2.0   2010
# 34  12.0   2010
# 35  17.0   2010
# 36   NaN   2010
# 37   9.0   2000
# 38   6.0   1990
# 39   6.0   2010
# 40   NaN   2010
# 41   2.0   1990
# 42   7.0   2000
# 43   NaN   2000
# 44   NaN   1990
# 45   4.0   1990

# %%
salma_mexico=pd.merge(peliculas_mexicanas,salma, left_on="title", right_on="title", how="inner")[["title","date"]].set_index("title")

# %%
salma_mexico.sort_values("date")
# Out:
#                                                      date
# title
# From Dusk Till Dawn                            1996-06-14
# Four Rooms                                     1996-11-13
# Fools Rush In                                  1997-05-16
# El coronel no tiene quien le escriba           1999-09-16
# Traffic                                        2001-03-19
# La gran vida                                   2001-06-01
# Frida                                          2002-11-20
# Spy Kids 3-D: Game Over                        2003-10-10
# Once Upon a Time in Mexico                     2003-10-24
# After the Sunset                               2005-01-14
# Bandidas                                       2006-02-17
# Ask the Dust                                   2006-11-17
# Lonely Hearts                                  2007-07-20
# Across the Universe                            2007-11-16
# Hotel                                          2008-05-29
# Cirque du Freak: The Vampire's Assistant       2009-10-30
# Grown Ups                                      2010-07-23
# Fair Game                                      2011-03-25
# Puss in Boots                                  2011-10-28
# The Pirates! In an Adventure with Scientists!  2012-04-20
# Savages                                        2012-07-13
# La chispa de la vida                           2012-11-02
# Americano                                      2012-12-07
# Here Comes the Boom                            2012-12-28
# Grown Ups 2                                    2013-08-16
# How to Make Love Like an Englishman            2015-09-03
# The Prophet                                    2016-01-22
# Sausage Party                                  2016-10-30

# %% [markdown]
# * En que dia de la semana se han lanzado en USA las peliculas donde aparece ``Tom Cruise``. Incluir un grafico

# %%
cast
# Out:
#          Unnamed: 0.1  Unnamed: 0                   title  year
# 0                   0           0          Closet Monster  2015  \
# 1                   1           1         Suuri illusioni  1985
# 2                   2           2     Battle of the Sexes  2017
# 3                   3           3    Secret in Their Eyes  2015
# 4                   4           4              Steve Jobs  2015
# ...               ...         ...                     ...   ...
# 3564645         99995      899995                 Nanking  2007
# 3564646         99996      899996    Natural Born Killers  1994
# 3564647         99997      899997  No Country for Old Men  2007
# 3564648         99998      899998           North Country  2005
# 3564649         99999      899999          Now You See Me  2013
#
#                     name   type                character     n decada
# 0               Buffy #1  actor                  Buffy 4  31.0   2010
# 1                 Homo $  actor                   Guests  22.0   1980
# 2                $hutter  actor          Bobby Riggs Fan  10.0   2010
# 3                $hutter  actor          2002 Dodger Fan   NaN   2010
# 4                $hutter  actor  1988 Opera House Patron   NaN   2010
# ...                  ...    ...                      ...   ...    ...
# 3564645  Woody Harrelson  actor               Bob Wilson  13.0   2000
# 3564646  Woody Harrelson  actor              Mickey Knox   2.0   1990
# 3564647  Woody Harrelson  actor             Carson Wells   4.0   2000
# 3564648  Woody Harrelson  actor               Bill White   6.0   2000
# 3564649  Woody Harrelson  actor         Merritt McKinney   3.0   2010
#
# [3564650 rows x 9 columns]

# %%
from datetime import datetime

peliculas_USA=estreno[estreno.country=="USA"]
tom_cruise=cast[cast.name=="Tom Cruise"]

# %%
#merge peliculas USA con estrenos de tom cruise por título
tom_USA=pd.merge(peliculas_USA, tom_cruise, left_on="title", right_on="title", how="inner")[["title", "date"]].set_index("title")

tom_USA["fecha"]=pd.to_datetime(tom_USA["date"])
#crear columna "dia", a partir de la columna "date"

# %%
tom_USA.drop(columns=["date"], inplace=True)

# %%
tom_USA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, A Few Good Men to War of the Worlds
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    54 non-null     object
#  1   fecha   54 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.3+ KB

# %%
tom_USA["diasemana"]=tom_USA["fecha"].dt.day_name()
tom_USA
# Out:
#                                                           date      fecha
# title
# A Few Good Men                                      1992-12-11 1992-12-11  \
# All the Right Moves                                 1983-10-21 1983-10-21
# American Made                                       2017-09-29 2017-09-29
# August                                              1996-04-19 1996-04-19
# Austin Powers in Goldmember                         2002-07-26 2002-07-26
# Austin Powers in Goldmember                         2002-07-26 2002-07-26
# Born on the Fourth of July                          1990-01-05 1990-01-05
# Cocktail                                            1988-07-29 1988-07-29
# Collateral                                          2004-08-06 2004-08-06
# Days of Thunder                                     1990-06-27 1990-06-27
# Edge of Tomorrow                                    2014-06-06 2014-06-06
# Endless Love                                        1981-07-17 1981-07-17
# Endless Love                                        2014-02-14 2014-02-14
# Eyes Wide Shut                                      1999-07-16 1999-07-16
# Far and Away                                        1992-05-22 1992-05-22
# Interview with the Vampire: The Vampire Chronicles  1994-11-11 1994-11-11
# Jack Reacher                                        2012-12-21 2012-12-21
# Jack Reacher: Never Go Back                         2016-10-21 2016-10-21
# Jerry Maguire                                       1996-12-13 1996-12-13
# Knight and Day                                      2010-06-23 2010-06-23
# Legend                                              1986-04-18 1986-04-18
# Legend                                              2015-11-20 2015-11-20
# Lions for Lambs                                     2007-11-09 2007-11-09
# Losin' It                                           1983-04-22 1983-04-22
# Magnolia                                            2000-01-07 2000-01-07
# Minority Report                                     2002-06-21 2002-06-21
# Mission: Impossible                                 1996-05-22 1996-05-22
# Mission: Impossible - Ghost Protocol                2011-12-21 2011-12-21
# Mission: Impossible - Rogue Nation                  2015-07-31 2015-07-31
# Mission: Impossible II                              2000-05-24 2000-05-24
# Mission: Impossible III                             2006-05-05 2006-05-05
# Oblivion                                            2013-04-19 2013-04-19
# Rain Man                                            1988-12-16 1988-12-16
# Risky Business                                      1926-10-04 1926-10-04
# Risky Business                                      1939-03-03 1939-03-03
# Risky Business                                      1983-08-05 1983-08-05
# Rock of Ages                                        2012-06-15 2012-06-15
# Taps                                                1981-12-25 1981-12-25
# The Big Short                                       2015-12-23 2015-12-23
# The Color of Money                                  1986-10-17 1986-10-17
# The Firm                                            1993-06-30 1993-06-30
# The Last Samurai                                    1997-02-28 1997-02-28
# The Last Samurai                                    2003-12-05 2003-12-05
# The Mummy                                           1932-12-22 1932-12-22
# The Mummy                                           1959-12-16 1959-12-16
# The Mummy                                           1999-05-07 1999-05-07
# The Mummy                                           2017-06-09 2017-06-09
# The Outsiders                                       1983-03-25 1983-03-25
# The Queen                                           2006-11-17 2006-11-17
# Top Gun                                             1986-05-16 1986-05-16
# Tropic Thunder                                      2008-08-13 2008-08-13
# Valkyrie                                            2008-12-25 2008-12-25
# Vanilla Sky                                         2001-12-14 2001-12-14
# War of the Worlds                                   2005-06-29 2005-06-29
#
#                                                     diasemana
# title
# A Few Good Men                                         Friday
# All the Right Moves                                    Friday
# American Made                                          Friday
# August                                                 Friday
# Austin Powers in Goldmember                            Friday
# Austin Powers in Goldmember                            Friday
# Born on the Fourth of July                             Friday
# Cocktail                                               Friday
# Collateral                                             Friday
# Days of Thunder                                     Wednesday
# Edge of Tomorrow                                       Friday
# Endless Love                                           Friday
# Endless Love                                           Friday
# Eyes Wide Shut                                         Friday
# Far and Away                                           Friday
# Interview with the Vampire: The Vampire Chronicles     Friday
# Jack Reacher                                           Friday
# Jack Reacher: Never Go Back                            Friday
# Jerry Maguire                                          Friday
# Knight and Day                                      Wednesday
# Legend                                                 Friday
# Legend                                                 Friday
# Lions for Lambs                                        Friday
# Losin' It                                              Friday
# Magnolia                                               Friday
# Minority Report                                        Friday
# Mission: Impossible                                 Wednesday
# Mission: Impossible - Ghost Protocol                Wednesday
# Mission: Impossible - Rogue Nation                     Friday
# Mission: Impossible II                              Wednesday
# Mission: Impossible III                                Friday
# Oblivion                                               Friday
# Rain Man                                               Friday
# Risky Business                                         Monday
# Risky Business                                         Friday
# Risky Business                                         Friday
# Rock of Ages                                           Friday
# Taps                                                   Friday
# The Big Short                                       Wednesday
# The Color of Money                                     Friday
# The Firm                                            Wednesday
# The Last Samurai                                       Friday
# The Last Samurai                                       Friday
# The Mummy                                            Thursday
# The Mummy                                           Wednesday
# The Mummy                                              Friday
# The Mummy                                              Friday
# The Outsiders                                          Friday
# The Queen                                              Friday
# Top Gun                                                Friday
# Tropic Thunder                                      Wednesday
# Valkyrie                                             Thursday
# Vanilla Sky                                            Friday
# War of the Worlds                                   Wednesday

# %%
plt.rcParams["figure.figsize"] = (25,5)
plt.xticks(rotation=45)
plt.plot(tom_USA["diasemana"])

# %% [markdown]
# * ¿Que peliculas han sido lanzadas en la mayor cantidad de paises?, incluir en un grafico las 5 mayores.

# %%
estreno[["title","country"]].sort_values("title")
# Out:
#                           title               country
# 0         #73, Shaanthi Nivaasa                 India
# 1                       #Beings               Romania
# 2        #Ewankosau saranghaeyo           Philippines
# 3                       #Horror                   USA
# 4                       #Horror                    UK
# ...                         ...                   ...
# 443530  xXx: State of the Union             Hong Kong
# 443531  xXx: State of the Union               Hungary
# 443523  xXx: State of the Union  United Arab Emirates
# 443555  xXx: State of the Union                Greece
# 245852                      NaN                   USA
#
# [443556 rows x 2 columns]

# %%
nº_paises=estreno.groupby("country").ngroups 
nº_paises #189 paises distintos
# Out:
# 189

# %%
peliculas_por_pais=estreno[["country","title"]].groupby("country").count().sort_values(by="title",ascending=False)
#nº de peliculas estrenadas en cada pais
peliculas_por_pais.head(15)
# Out:
#               title
# country
# USA           43811
# France        23956
# Finland       18829
# Portugal      18623
# Denmark       17850
# Sweden        17575
# Japan         16950
# UK            15558
# Italy         13103
# Mexico        12470
# India         11883
# West Germany  11316
# Spain         10393
# Netherlands   10389
# Australia     10196

# %%
plt.plot(peliculas_por_pais.head(5))

# %%
estrenos_x_paises=estreno[["title", "country"]].groupby("title")
estrenos_x_paises.count().sort_values(by="country", ascending=False).head(15)
# Out:
#                               country
# title
# Fantastic Four                    136
# The Three Musketeers              125
# Hercules                          120
# The Avengers                      120
# Godzilla                          117
# Carrie                            109
# Anna Karenina                     109
# Alice in Wonderland               107
# RoboCop                           107
# The Jungle Book                   104
# Teenage Mutant Ninja Turtles      103
# Poltergeist                       100
# King Kong                          99
# Annie                              97
# Fury                               95

# %% [markdown]
# * ¿Quien tiende a ser el actor si clasificado (n > 1) que mas ha participado en peliculas donde el protagonista es ``Leonardo DiCaprio``?

# %%
cast.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0                 title  year      name   type
# 0             0           0        Closet Monster  2015  Buffy #1  actor  \
# 1             1           1       Suuri illusioni  1985    Homo $  actor
# 2             2           2   Battle of the Sexes  2017   $hutter  actor
# 3             3           3  Secret in Their Eyes  2015   $hutter  actor
# 4             4           4            Steve Jobs  2015   $hutter  actor
#
#                  character     n
# 0                  Buffy 4  31.0
# 1                   Guests  22.0
# 2          Bobby Riggs Fan  10.0
# 3          2002 Dodger Fan   NaN
# 4  1988 Opera House Patron   NaN

# %%
leonardo=cast[["title"]][cast.name=="Leonardo DiCaprio"]
leonardo
# Out:
#                                          title
# 3226908                          Blood Diamond
# 3226909                           Body of Lies
# 3226910                    Catch Me If You Can
# 3226911                              Celebrity
# 3226912                             Critters 3
# 3226913                       Django Unchained
# 3226914                             Don's Plum
# 3226915                      Gangs of New York
# 3226916                              Inception
# 3226917                               J. Edgar
# 3226918                          Marvin's Room
# 3226919  Model Culture: One + Night in Bangkok
# 3226920                             Poison Ivy
# 3226921                     Revolutionary Road
# 3226922                         Romeo + Juliet
# 3226923                         Shutter Island
# 3226924                            The Aviator
# 3226925                 The Basketball Diaries
# 3226926                              The Beach
# 3226927                           The Departed
# 3226928                       The Great Gatsby
# 3226929               The Man in the Iron Mask
# 3226930               The Man in the Iron Mask
# 3226931                 The Quick and the Dead
# 3226932                           The Revenant
# 3226933                The Wolf of Wall Street
# 3226934                        This Boy's Life
# 3226935                                Titanic
# 3226936                          Total Eclipse
# 3226937            What's Eating Gilbert Grape

# %%
actores_pelicula_leonardo=pd.merge(leonardo, cast[["title", "name", "n"]], left_on="title", right_on="title", how="inner")

# %%
actores_pelicula_leonardo
# Out:
#                             title                 name     n
# 0                   Blood Diamond  Martin Abdul-Jabbar  29.0
# 1                   Blood Diamond            Dan Hirst   NaN
# 2                   Blood Diamond      Mlungisi Hlophe  47.0
# 3                   Blood Diamond       Djimon Hounsou   2.0
# 4                   Blood Diamond         Tyrone Keogh  42.0
# ...                           ...                  ...   ...
# 3174  What's Eating Gilbert Grape      Peter Fernandez  29.0
# 3175  What's Eating Gilbert Grape       Cameron Finley  16.0
# 3176  What's Eating Gilbert Grape       Crispin Glover  10.0
# 3177  What's Eating Gilbert Grape            Tim Green  12.0
# 3178  What's Eating Gilbert Grape     Daniel Gullahorn  25.0
#
# [3179 rows x 3 columns]

# %%
actores_pelicula_leonardo[(actores_pelicula_leonardo.n>1)&(actores_pelicula_leonardo.name!="Leonardo DiCaprio")].groupby("name").agg("count").sort_values("n", ascending=False).head(10)
# Out:
#                  title  n
# name
# Joseph P. Reidy      4  4
# Jerry Swindall       3  3
# Tobey Maguire        3  3
# Steve Witting        3  3
# Nellie Sciutto       3  3
# Edward Herrmann      3  3
# John C. Reilly       3  3
# J.C. MacKenzie       3  3
# Michael Moon         2  2
# Richard Graham       2  2
